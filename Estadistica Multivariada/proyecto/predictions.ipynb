# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
logged_model = 'runs:/2bf1e65bc8df4636a14731ebac78f738/lda_model'

# Load model as a PyFuncModel.
loaded_model = mlflow.sklearn.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
loaded_model.intercept_
# Out:
# array([-1.61355098])

# %%
loaded_model.get_params()
# Out:
# {'covariance_estimator': None,
#  'n_components': 1,
#  'priors': (0.5, 0.5),
#  'shrinkage': None,
#  'solver': 'svd',
#  'store_covariance': False,
#  'tol': 0.0001}

# %%
loaded_model.scalings_.T.dot(loaded_model.scalings_)
# Out:
# array([[1.26710949]])

# %%
loaded_model.coef_
# Out:
# array([[-0.09926833, -0.05398064, -0.08348242, -0.04242468,  0.10177629,
#         -0.06477497, -0.05048746,  0.13898756, -0.05502595, -0.0184912 ,
#         -0.02174277, -0.09584733,  0.0486049 ,  0.05932743,  0.14942999,
#          0.02116783,  0.07820724,  1.04599409, -0.02747457, -0.02747445,
#         -0.54882144, -0.00751513, -0.33473362, -0.12194422, -0.36027312,
#          0.14476959, -0.04992554, -0.27030169, -0.37022185,  0.06471965,
#          0.37664384, -0.22627337, -0.30329439,  0.27050275,  0.24553023,
#          0.01391755,  0.06159357,  0.11957696,  1.70208263, -0.05610991,
#         -0.04729832,  0.04008815]])

# %%
madre = loaded_model.coef_.copy()

# %%
madre[0,38] = 0.21273963

# %%
madre
# Out:
# array([[-0.09926833, -0.05398064, -0.08348242, -0.04242468,  0.10177629,
#         -0.06477497, -0.05048746,  0.13898756, -0.05502595, -0.0184912 ,
#         -0.02174277, -0.09584733,  0.0486049 ,  0.05932743,  0.14942999,
#          0.02116783,  0.07820724,  1.04599409, -0.02747457, -0.02747445,
#         -0.54882144, -0.00751513, -0.33473362, -0.12194422, -0.36027312,
#          0.14476959, -0.04992554, -0.27030169, -0.37022185,  0.06471965,
#          0.37664384, -0.22627337, -0.30329439,  0.27050275,  0.24553023,
#          0.01391755,  0.06159357,  0.11957696,  0.21273963, -0.05610991,
#         -0.04729832,  0.04008815]])

# %%
import pandas as pd
data = pd.read_csv("./data/test.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9043 entries, 0 to 9042
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   onehot__job_blue-collar        9043 non-null   float64
#  1   onehot__job_entrepreneur       9043 non-null   float64
#  2   onehot__job_housemaid          9043 non-null   float64
#  3   onehot__job_management         9043 non-null   float64
#  4   onehot__job_retired            9043 non-null   float64
#  5   onehot__job_self-employed      9043 non-null   float64
#  6   onehot__job_services           9043 non-null   float64
#  7   onehot__job_student            9043 non-null   float64
#  8   onehot__job_technician         9043 non-null   float64
#  9   onehot__job_unemployed         9043 non-null   float64
#  10  onehot__job_unknown            9043 non-null   float64
#  11  onehot__marital_married        9043 non-null   float64
#  12  onehot__marital_single         9043 non-null   float64
#  13  onehot__education_secondary    9043 non-null   float64
#  14  onehot__education_tertiary     9043 non-null   float64
#  15  onehot__education_unknown      9043 non-null   float64
#  16  onehot__poutcome_other         9043 non-null   float64
#  17  onehot__poutcome_success       9043 non-null   float64
#  18  onehot__poutcome_unknown       9043 non-null   float64
#  19  onehot__contact_telephone      9043 non-null   float64
#  20  onehot__contact_unknown        9043 non-null   float64
#  21  onehot__default_yes            9043 non-null   float64
#  22  onehot__housing_yes            9043 non-null   float64
#  23  onehot__loan_yes               9043 non-null   float64
#  24  onehot__month_aug              9043 non-null   float64
#  25  onehot__month_dec              9043 non-null   float64
#  26  onehot__month_feb              9043 non-null   float64
#  27  onehot__month_jan              9043 non-null   float64
#  28  onehot__month_jul              9043 non-null   float64
#  29  onehot__month_jun              9043 non-null   float64
#  30  onehot__month_mar              9043 non-null   float64
#  31  onehot__month_may              9043 non-null   float64
#  32  onehot__month_nov              9043 non-null   float64
#  33  onehot__month_oct              9043 non-null   float64
#  34  onehot__month_sep              9043 non-null   float64
#  35  numeric_passthrough__age       9043 non-null   float64
#  36  numeric_passthrough__balance   9043 non-null   float64
#  37  numeric_passthrough__day       9043 non-null   float64
#  38  numeric_passthrough__duration  9043 non-null   float64
#  39  numeric_passthrough__campaign  9043 non-null   float64
#  40  numeric_passthrough__pdays     9043 non-null   float64
#  41  numeric_passthrough__previous  9043 non-null   float64
#  42  y                              9043 non-null   int64
# dtypes: float64(42), int64(1)
# memory usage: 3.0 MB
