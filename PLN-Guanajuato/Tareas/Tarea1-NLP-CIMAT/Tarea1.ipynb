# %% [markdown]
# ## Tarea 1 - NLP CIMAT: Python
# ##### Por: Gustavo Hernández Angeles
#
# * La carpeta `clean_estenograficas` y el archivo `corpus.txt` deben estar en el mismo directorio que este notebook.

# %%
import glob

# %% [markdown]
# ## 1. Construcción de un corpus

# %%
corpus = open(".\\corpus.txt", "r", encoding="utf-8").read()

# %% [markdown]
# ## 2. Vistazo a los datos

# %% [markdown]
# #### 1. **Cargue todas las conferencias en un *string* y aplique la función *split* para generar tokens facilmente.**

# %%
tokens = corpus.split()

# %% [markdown]
# #### 2. **Contar la cantidad de palabras en todas las conferencias.**

# %%
n_palabras = len(tokens)
print("Numero total de palabras:",n_palabras)
# Out:
# Numero total de palabras: 16465189

# %% [markdown]
# #### 3. **Extraer el vocabulario y mostrar su longitud de todo el corpus.**

# %%
n_vocabulario = len(set(tokens))
print("Tamaño del vocabulario:",n_vocabulario)
# Out:
# Tamaño del vocabulario: 262016

# %% [markdown]
# #### 4. **Mida la riqueza del vocabulario de alguna forma en todos los documentos.**

# %%
# Podemos medir la riqueza mediante
razon = n_palabras/n_vocabulario
print("Razón no. términos entre el vocabulario:", razon)
# Out:
# Razón no. términos entre el vocabulario: 62.84039524303859

# %% [markdown]
# #### 5. **Haga lo mismo que los 4 puntos anteriores pero con todo el texto en minúsculas. Vea las diferencias y comente brevemente.**

# %%
# Todo el texto en minúsculas.
tokens_minusculas = corpus.lower().split()

print("Número de términos:",len(tokens_minusculas))
print("Tamaño de vocabulario:",len(set(tokens_minusculas)))
print("Razón no. términos entre el vocabulario:", len(tokens_minusculas)/len(set(tokens_minusculas)))
# Out:
# Número de términos: 16465189
# Tamaño de vocabulario: 239383
# Razón no. términos entre el vocabulario: 68.78178066111629

# %% [markdown]
# * El número total de términos se mantiene invariante, lo cual es normal.
# * El tamaño del vocabulario decrece debido a que, palabras que se diferenciaban mediante el uso de mayúscula (e.g. "caballo" y "Caballo"), ahora se cuentan como una misma.
# * A consecuencia de lo anterior, la razón entre el tamaño del número de terminos entre el vocabulario crece; pasando de $\sim 62.84$ a $\sim 68.78$.

# %% [markdown]
# #### 6. **Haga lo mismo que los puntos 1, 2 y 3 usando el tokenizador *RegExp* de NLTK, con una expresión regular que trate de sacar solo tokens que pueden contener solo letras mayúsculas y minúsculas. Después cargue los tokens en un objeto *Text* de NLTK en lugar de una lista de Python.**

# %%
import nltk
from nltk.tokenize import RegexpTokenizer

# 1. Generamos los tokens con RegexpTokenizer.
# La expresión regular aceptará solo palabras con carácteres comunes en
# español.
re_tokenizer = r'[a-zA-ZáéíóúñÁÉÍÓÚÑ]+'
tokenizer = RegexpTokenizer(re_tokenizer)
text_conferencias = tokenizer.tokenize(corpus) # Tokens
text_conferencias = nltk.text.Text(text_conferencias)

# 2. Número total de términos
print("Numero total de tokens:", len(text_conferencias))

# 3. Tamaño del vocabulario
print("Tamaño del vocabulario:", len(set(text_conferencias)))
# Out:
# Numero total de tokens: 16264559
# Tamaño del vocabulario: 106649

# %% [markdown]
# #### 7. **Haga todo el texto minúsculas. Haga los mismo que los puntos 1, 2 y 3 usando el tokenizados *TweetTokenizer*; COMENTE BREVEMENTE DIFERENCIAS. Haga el resto de esta tarea asumiendo haber hecho este punto.**

# %%
from nltk.tokenize import TweetTokenizer

# 1. Generamos los tokens con TweetTokenizer.
tw_tokenizer = TweetTokenizer()
twitter_text_conferencias = tw_tokenizer.tokenize(corpus.lower()) # Tokens
twitter_text_conferencias = nltk.text.Text(twitter_text_conferencias)

# 2. Número total de términos
print("Numero total de tokens:", len(twitter_text_conferencias))

# 3. Tamaño del vocabulario
print("Tamaño del vocabulario:", len(set(twitter_text_conferencias)))
# Out:
# Numero total de tokens: 19163452
# Tamaño del vocabulario: 98637

# %% [markdown]
# * El TweetTokenizer está hecho para tokenizar carácteres o secuencias de carácteres importantes para los tweets; "hashtags", emoticonos, simbolos y @usuarios en este ejemplo. Mientras que el primer tokenizador solo toma en cuenta las palabras con mayúsculas o minúsculas.
#
# * Esto tiene como consecuencia un mayor número de términos para el TweetTokenizer. Aunque en tamaño del vocabulario gana RegexpTokenizer, por las distintas formas de escribir las palabras con mayúsculas y minúsculas. Al menos eso creo.

# %%
tweet = "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <-- @remy: This is waaaaayyyy too much for you!!!!!!"
print(nltk.text.Text(tw_tokenizer.tokenize(tweet)))
# Out:
# <Text: This is a cooool #dummysmiley : :-) :-P...>

# %% [markdown]
# ## 3. Funciones NLTK

# %% [markdown]
# #### 1. Use la función *concordance* para ver el contexto de 5 palabras que usted elija.

# %%
palabras = [
    "justicia",
    "pueblo",
    "fox",
    "gobiernos",
    "delincuencia"
]

for palabra in palabras:
    text_conferencias.concordance(palabra)
# Out:
# Displaying 25 of 6111 matches:
# os muchas cosas buenas a favor Sin justicia no hay garantía de seguridad tranq
# Conferencia de prensa matutina Sin justicia no hay garantía de seguridad tranq
#  presidente de la Suprema Corte de Justicia fue directo al problema de la corr
# mo sin ninguna limitación que haya justicia A ver acá porque no quiero que tú
# n mantener fuera del alcance de la justicia este acto que han padecido Esa es
# y la tranquilidad son frutos de la justicia Entonces es complementario Son pro
# erdad creo que el que lucha por la justicia no tiene nada que temer De todas f
# s ministros de la Suprema Corte de Justicia la mayoría por corrupción El puebl
#  ministro para la Suprema Corte de Justicia Está vacante el lugar del ministro
# agistrada del Tribunal Superior de Justicia en el Estado de Querétaro Es egres
# residente del Tribunal Superior de Justicia del Distrito Federal ahora Ciudad
# uello que no afecte el que se haga justicia debe de haber de transparencia por
#  y los sueldos la Suprema Corte de Justicia ya dijo que va a definir los crite
# ga que es el encargado de impartir justicia Se me hace una contradicción Eso n
# s conscientes de que debe de haber justicia y protección para todos los period
# o Todo lo que tiene que ver con la justicia para conocer la verdad de Ayotzina
# es parte del propósito de que haya justicia de que se conozca el paradero de l
# to ahorita que la Suprema Corte de Justicia ya dio atrás a la Ley de Remunerac
# está demandando la gente ni con la justicia Al contrario Es una arbitrariedad
# rabajando para garantizar que haya justicia en Chiapas y en todo el país Sobre
# er Judicial Es la Suprema Corte de Justicia de la Nación No es la Suprema Cort
# Suprema Corte del Derecho es de la Justicia Se dice que cuando hay que optar e
# ay que optar entre el derecho y la justicia se debe de decidir por la justicia
# justicia se debe de decidir por la justicia Entonces es un asunto de ellos y t
# y la tranquilidad son frutos de la justicia Si hay trabajo va a haber paz y va
# Displaying 25 of 21085 matches:
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# neral incluido los soldados que son pueblo uniformado Todos me protegen y me c
#  relación con los ciudadanos con el pueblo No quiero que me cerquen No quiero
#  usted considera la cercanía con el pueblo mexicano un activo para el presiden
# n Y usted ha dicho que confía en el pueblo pero confía también en que los crim
# dos y ministros sean votados por el pueblo porque hoy la mayoría como se los d
# sticia la mayoría por corrupción El pueblo tiene que elegir a sus jueces señor
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# ue no puede haber Gobierno rico con pueblo pobre No es posible que un servidor
# dor es libre Son representantes del pueblo de las entidades federativas y ello
# os a robar No vamos a traicionar al pueblo Entonces se envía la terna si exist
# agan un ofrecimiento de disculpa al pueblo de México Porque se acuerdan cómo b
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# to no puede haber Gobierno rico con pueblo pobre Juárez decía El funcionario t
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
#  de salud Es una gente vinculada al pueblo cercana a los ciudadanos Y sí lo vo
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# tá trabajando Y voy a informarle al pueblo de México es decir fíjense se estre
# ro no puede haber gobierno rico con pueblo pobre Se me hace una injusticia que
# no no se le transferían recursos al pueblo Ahora que fui a Nayarit a ver a los
# al gobierno Entréguele el dinero al pueblo Y si lo analizamos de los cinco bil
# a gente opine Qué se decía antes El pueblo no cuenta la política es asunto de
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# endencia en el sexenio saludamos al pueblo y reconocimos la participación de t
# Displaying 25 of 1598 matches:
# plan de salud el expresidente Vicente Fox dijo que no está de acuerdo que no le
# usted que desde el sexenio de Vicente Fox se tenía registro del robo Entonces u
# abía desde el gobierno del presidente Fox es más se descontaba del presupuesto
# arlos Salinas Ernesto Zedillo Vicente Fox Felipe Calderón Enrique Peña Nieto po
# a los de arriba a ver Salinas Zedillo Fox Calderón Peña Nieto o vamos hacia ade
# Secretaría de Hacienda en la época de Fox lo tenía contemplado como parte del p
# lo había visto Yo creo que lo vio más Fox y Calderón como dato nada más Muchas
# ay un caso histórico en el sexenio de Fox una subsecretaría del consumidor fue
# Los expresidentes panistas Calderón y Fox PRESIDENTE ANDRÉS MANUEL LÓPEZ OBRADO
# L LÓPEZ OBRADOR Lo sabían todos desde Fox Quién le siguió Calderón PREGUNTA Ina
# ienda esto viene desde el gobierno de Fox que se robaban alrededor de mil millo
# iba desde Salinas pasando por Zedillo Fox Calderón y Peña Nieto Y es lo que pod
#  hasta Peña Nieto pasando por Zedillo Fox y Calderón porque lo que está pasando
# aba ahorita de los expresidentes ayer Fox le decía que lo retaba a demostrar có
# su postura respecto a esta opinión de Fox de que se le denigra al ligarlo con e
#  voy a caer en ninguna provocación de Fox Y acerca de lo que dice el gobernador
# eo a venderse a dólares el barril con Fox y sobre todo con Calderón A dónde fue
# los autotanques viene desde tiempo de Fox sin pasar por una licitación ahora co
# añana publica el expresidente Vicente Fox señalando que Olga Sánchez Cordero y
# harme con ese asunto del expresidente Fox él está muy activo opinando bastante
# pero usted no se quería enganchar con Fox lo voy a enganchar con Fox Fíjese que
# anchar con Fox lo voy a enganchar con Fox Fíjese que en el yo estaba entrevista
# los Aguirre me dijeron Vámonos porque Fox nos está esperando Entonces Ebrard di
# os y oh sorpresa estaba el presidente Fox con Luis Carlos Ugalde presidente del
# ismo Usted no se quería enganchar con Fox pero yo creo que ya se enganchó en es
# Displaying 25 of 4010 matches:
# licía lleva como años ha estado en gobiernos de distintos partidos y es bueno e
# Cuando no hay participación de los gobiernos locales pues nosotros tenemos que
#  de los servidores públicos de los gobiernos pasados con los actuales ya está m
#  Eso no estaba en la agenda de los gobiernos anteriores no aparecía el tema ni
# efecto impactó tanto el que en los gobiernos anteriores se hayan llevado a cabo
# erdo de inversión entre empresas y gobiernos para impulsar actividades producti
#  al servicio del Gobierno o de los gobiernos estatales El compromiso es adelant
# iten Nosotros vamos a apoyar a los gobiernos estatales a los gobiernos municipa
# ar a los gobiernos estatales a los gobiernos municipales pero siempre de confor
# oordinaciones en algunos casos los gobiernos estatales ya están participando en
# Cervera Pacheco y han pasado otros gobiernos ahí ha gobernado el PRI ha goberna
# erdo de inversión entre empresas y gobiernos de Canadá de Estados Unidos México
# nadá de Estados Unidos México y de gobiernos centroamericanos para enfrentar de
# n significa que hay países que sus gobiernos su sector privado han tenido mayor
# e si también tiene que ver con los gobiernos locales como se ha sabido que func
# está atendiendo lo fundamental Los gobiernos de los estados están recibiendo pa
#  que están ahora manejados por los gobiernos estatales las unidades médicas rur
# ntes municipales al Congreso había gobiernos que preparaban comida si eran del
# eniendo muy buena relación con los gobiernos centroamericanos que todos estos p
#  lo hemos hecho en compañía de los gobiernos de Centroamérica Yo les recuerdo q
# d y los hospitales dependen de los gobiernos estatales las unidades médicas dep
# s entregaban esas autorizaciones a gobiernos municipales gobiernos estatales a
# rizaciones a gobiernos municipales gobiernos estatales a cambio de sobornos Eso
# dente preguntarle si alguno de los gobiernos estatales le ha solicitado o bueno
# ara la corrupción porque desde los gobiernos se hacían las contrataciones de em
# Displaying 25 of 2632 matches:
#  contubernio entre autoridades y delincuencia Estamos resolviendo todo eso y a
# armente aquellos vinculados a la delincuencia organizada en contrapartida esto
# aquí un total de afectación a la delincuencia organizada de mil millones mil p
#  el porcentaje mayor se da en la delincuencia organizada o la llamada delincue
# ncuencia organizada o la llamada delincuencia organizada A ver vamos a poner u
# uántos de los tienen que ver con delincuencia organizada ALFONSO DURAZO MONTAÑ
#  había así las bandas existía la delincuencia pero no era vamos a decir delinc
# uencia pero no era vamos a decir delincuencia organizada como ahora Nosotros c
# ínea divisoria entre autoridad y delincuencia Si se le da protección a la deli
# ncia Si se le da protección a la delincuencia no se avanza Miren lo que está s
# n subordinados al servicio de la delincuencia que no estén siendo sobornados p
# o estén siendo sobornados por la delincuencia que no se tolere la delincuencia
# delincuencia que no se tolere la delincuencia eso ayuda mucho Esa es tu Ahora
# ico y también tiene problemas de delincuencia organizada se ha reconocido que
#  no caigan en la tentación de la delincuencia Ahora va a haber trabajo para to
# ya la frontera entre autoridad y delincuencia Ya cuando no existe esa frontera
# sta plataforma de información de delincuencia organizada que se va a revivir e
# poder avanzar en el combate a la delincuencia La segunda es el subsecretario E
#  que fue subprocurador contra la delincuencia organizada luego el caso de Blak
# la seguridad y hacer frente a la delincuencia dentro de un marco de respeto a
# lica y atender el problema de la delincuencia mediante procedimientos policial
#  de Homicidios Vinculados con la Delincuencia Organizada Es importante recorda
# rupos ligados presuntamente a la delincuencia organizada ha generado niveles d
# obligado a tomar el camino de la delincuencia En eso estamos y ahí les dejo de
# o dejarnos someter vencer por la delincuencia que entre todos triunfemos y aca

# %% [markdown]
# #### 2. Elija una palabra que le parezca interesante y muestre palabras con uso similar. Muestre también los contextos comunes.

# %%
text_conferencias.similar("tren")
# Out:
# país estado gobierno año día presidente pueblo tema tiempo trabajo que
# caso y programa presupuesto proceso aeropuerto mundo proyecto dinero

# %%
text_conferencias.common_contexts(["tren","muy"])
# Out:
# y_de un_ligero del_importante es_y también_de de_bajo del_cerca y_en
# como_de es_de no_de de_distinto

# %% [markdown]
# #### 3. Haciendo uso de alguna librería *time* de Python: organice todos los archivos de las conferencias desde la más antigua hasta la más nueva (echando mano del nombre del archivo y fechas), y cárguelos en un objeto *Text* para generar un *dispersion plot* de las siguientes palabras: *prian*, *corrupción*, *mafia*, *narco*, *gasolina*, pipas, conacyt, conahcyt, ciencia, turismo, pandemia, coronavirus, covid, delta, omicron, vacuna, vacunacion y otras cinco palabras de su elección.

# %% [markdown]
# * Haré uso de la función `dispersion_plot` directamente de nltk.draw, ya que esta función si me permite ignorar que sean mayúsculas o minúsculas.
#
# De estas gráficas podemos notar varias cosas:
#
# * La palabra **"corrupción"** y **"gasolina"** han sido de constante uso durante el sexenio de Obrador, y sigue vigente con la actual presidenta.
# * Si bien la palabra **"narco"** y **"mafia"** estuvieron relativamente presentes, no fue hasta más de la segunda mitad donde se empezaron a usar con mayor frecuencia.
# * Como se esperaría, las palabras **"conacyt"** y **"conahcyt"** tienen muy claros periodos disjuntos de uso.
#     - De hecho, el primero uso de la palabra **CONAHCYT** fue cuando se anunció, por ello está tan alejado.
# * A causa de la pandemia, las palabras **"pandemia"**, **"covid"**, **"vacuna"** y **"coronavirus"** son empezadas a usar en el mismo periodo de tiempo.
#     - **"COVID"** se convirtió en el término preferido para referirse al coronavirus.
#     - Tiempo después del inicio, **"Delta"** empieza a ser utilizada a causa de la variante, aunque en un periodo corto de tiempo.
#     - La distribución de **"Vacuna"** fue bajando con el tiempo.
#     - **"Pandemia"** ha sido constante desde su inicio.

# %%
from nltk.draw import dispersion_plot

palabras1 = [
    "prian",
    "corrupción",
    "mafia",
    "narco",
    "gasolina",
    "pipas",
    "conacyt",
    "conahcyt"
]

palabras2 = [
    "ciencia",
    "turismo",
    "pandemia",
    "coronavirus",
    "covid",
    "delta",
    "omicron",
    "vacuna",
    "vacunacion"
]

palabras_eleccion = [
    "rifa",
    "maya",
    "covid",
    "Bocas",
    "xóchitl",
    "masacres"
]

dispersion_plot(text_conferencias, palabras1, ignore_case=True, title="Palabras Tarea: Parte 1")
dispersion_plot(text_conferencias, palabras2, ignore_case=True, title="Palabras Tarea: Parte 2")

dispersion_plot(text_conferencias, palabras_eleccion, ignore_case=True, title="Palabras Propuestas")
# Out:
# <Axes: title={'center': 'Palabras Propuestas'}, xlabel='Word Offset'>

# %% [markdown]
# #### 4. Muestre 50 colocaciones de todo el corpus.

# %% [markdown]
# * Mayormente se debe al nombre de los presidentes.
# * Nombres de estados como Baja California, Nuevo León, Quintana Roo.
# * Nombres de proyectos e instituciones.

# %%
text_conferencias.collocations(50)
# Out:
# ANDRÉS MANUEL; PRESIDENTE ANDRÉS; LÓPEZ OBRADOR; MANUEL LÓPEZ; Estados
# Unidos; por ciento; señor presidente; todos los; Buenos días; Guardia
# Nacional; nada más; Muchas gracias; mil millones; López Obrador; Tren
# Maya; Poder Judicial; Baja California; Andrés Manuel; RAMÍREZ CUEVAS;
# buenos días; JESÚS RAMÍREZ; que que; Quintana Roo; SHEINBAUM PARDO;
# CLAUDIA SHEINBAUM; muy importante; desde luego; sobre todo; creo que;
# MÉXICO CLAUDIA; Cuarta Transformación; todas las; Manuel López; por
# ejemplo; nuestro país; Por eso; Comisión Federal; adultos mayores; con
# centavos; derechos humanos; Fiscalía General; ver con; por eso; los
# mexicanos; García Luna; Nuevo León; sin embargo; tiene que; gobierno
# federal; los trabajadores

# %% [markdown]
# #### 5. Muestre un histograma de longitud en carácteres de las palabras. Muestre en el histograma el top 5 de longitudes más largas.

# %% [markdown]
# Podemos observar que hay palabras demasiado grandes, en el top 5 se encuentran longitudes que van desde 27 carácteres hasta 48!
#
# Comprobé, quise buscar esas palabras y resultó que eran partes de URL que se encuentran en las mañaneras.
#
# Por ejemplo, en "jovenesconstruyendoelfuturo.stps.gob.mx" se detectan las 4 palabras presentes, así, el tokenizador pensará que "jovenesconstruyendoelfuturo" es una palabra válida de 27 caracteres.

# %%
from nltk import FreqDist

longitudes = [len(palabra) for palabra in text_conferencias]
fdist = FreqDist(longitudes)

# %%
# Top 5 longitudes más largas
sorted(set(longitudes), reverse=True)[:5]
# Out:
# [48, 41, 33, 31, 27]

# %%
fdist.plot(48, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### 6. Muestre 50 palabras con longitud mayor a 8 caracteres y frecuencia mayor a 5 en todo el texto usando comprehension list de Python.

# %%
fdist = FreqDist(text_conferencias)

# %%
largas = [palabra for palabra, frecuencia in fdist.items() if len(palabra)> 8 and frecuencia > 5]
print(largas[:50])
largas.sort(key=fdist.get, reverse=True)
print(largas[:50])
# Out:
# ['PRESIDENTE', 'acordamos', 'presentar', 'seguridad', 'resultados', 'mexicanos', 'trabajando', 'inseguridad', 'violencia', 'reuniones', 'Seguridad', 'tendencia', 'elementos', 'instrumentos', 'enfrentar', 'legalmente', 'corrupción', 'contubernio', 'autoridades', 'delincuencia', 'resolviendo', 'avanzando', 'garantizar', 'tranquilidad', 'Conferencia', 'Publicado', 'diciembre', 'coordinada', 'institución', 'dependencia', 'trabajaba', 'perseverancia', 'atendiendo', 'importante', 'impunidad', 'construyendo', 'instalaciones', 'cuarteles', 'inteligencia', 'persiguiendo', 'opositores', 'propósito', 'estrategia', 'bienestar', 'moralizar', 'informarles', 'secretario', 'Protección', 'Ciudadana', 'Cresencio']
# ['presidente', 'PRESIDENTE', 'importante', 'INTERLOCUTOR', 'información', 'INTERLOCUTORA', 'Secretaría', 'corrupción', 'seguridad', 'mexicanos', 'trabajadores', 'secretario', 'trabajando', 'situación', 'presupuesto', 'elementos', 'investigación', 'INTERVENCIÓN', 'Presidente', 'violencia', 'construcción', 'Bienestar', 'población', 'República', 'gobernador', 'inversión', 'desarrollo', 'municipios', 'hospitales', 'comunicación', 'precisamente', 'autoridades', 'democracia', 'aeropuerto', 'Seguridad', 'gobiernos', 'solamente', 'siguiente', 'preguntarle', 'participación', 'compromiso', 'administración', 'Constitución', 'California', 'propósito', 'cualquier', 'educación', 'ciudadanos', 'secretaria', 'transformación']

# %% [markdown]
# #### 7. Ver https://www.nltk.org/book/ch02.html en la seccion 1.5. Proponga una gráfica usando *ConditionalFreqDist* como la sección 1.5 para estos datos. Usted elige las palabras.

# %% [markdown]
# En esta ocasión utilicé la carpeta `clean_estenograficas` para realizar el objeto *conditionalFreqDist*, ya que aún incluye información sobre el año.
#
# Lo hice contando las veces que se mencionaban las palabras "covid", "vacuna" y "pandemia" en cada año. Podemos ver ciertos detalles:
#
# * En 2019 no se habló nada de vacunas, covid y pandemia.
# * Se habló de las 3 palabras con la misma intensidad en 2020.
# * El año 2021 fue el pico más alto donde se habló de la vacuna, y el año en donde se empezó a aplicar.
# * La frecuencia con la que eran pronunciadas las palabras empezó a decaer exponencialmente desde ese año.
# * covid y pandemia fueron utilizadas con la misma frecuencia en todo el periodo.

# %%
# De forma similar al dispersion plot, veremos el uso de las palabras.
# a lo largo de los documentos.

cfd = nltk.ConditionalFreqDist(
    (word[:len(target)], documento[-14:-10])
    for documento in glob.glob(".\\clean_estenograficas\\*.txt")
    for word in open(documento, "r").read().lower().split()
    for target in ["vacuna", "covid", "pandemia"]
    if word.startswith(target)
)

# %%
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### 8. Use la lista de stopwords de nltk y obtenga la cantidad de palabras en los datos con y sin stopword. Comente brevemente las diferencias.

# %%
from nltk.corpus import stopwords

# %%
print(stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
stopwords_espanol = stopwords.words("spanish")
# Este objeto Text contiene los datos con stopwords, es el
# que hemos estado utilizando
text_conferencias

# Creamos un nuevo Text que no contenga las stopwords.
# Será con las palabras en minúsculas para la comparación en el
# siguiente punto.
text_conferencias_nosp = nltk.text.Text(
    [w.lower()
     for w in text_conferencias 
     if w.lower() not in stopwords_espanol]
)

# %%
print(f"Cantidad de palabras con stopwords: {len(text_conferencias)}.")
print(f"Cantidad de palabras sin stopwords: {len(text_conferencias_nosp)}.")
# Out:
# Cantidad de palabras con stopwords: 16264559.
# Cantidad de palabras sin stopwords: 7836769.

# %% [markdown]
# **¡El número de palabras se redujo en más de la mitad!**

# %% [markdown]
# #### 9. Muestre las 300 palabras más frecuentes en las conferencias, sin tomar en cuenta stop-words. Muéstrelas de la más frecuente a la menos frecuente.

# %%
# Para esto utilizaremos un objeto freqDist
freq_palabras = FreqDist(text_conferencias_nosp)

# %%
freq_palabras.plot(20, title="Primeras 20 palabras")
# Out:
# <Axes: title={'center': 'Primeras 20 palabras'}, xlabel='Samples', ylabel='Counts'>

# %%
freq_palabras.most_common(300)
# Out:
# [('presidente', 103490),
#  ('lópez', 56523),
#  ('si', 55898),
#  ('manuel', 53247),
#  ('obrador', 53200),
#  ('andrés', 52400),
#  ('entonces', 51907),
#  ('va', 47311),
#  ('vamos', 47294),
#  ('méxico', 46425),
#  ('mil', 45824),
#  ('aquí', 33053),
#  ('gobierno', 30874),
#  ('pues', 28156),
#  ('ver', 27392),
#  ('ahora', 26760),
#  ('dos', 26433),
#  ('bueno', 24511),
#  ('ahí', 24350),
#  ('caso', 23351),
#  ('millones', 23103),
#  ('cómo', 22373),
#  ('pregunta', 22295),
#  ('país', 21447),
#  ('pueblo', 21085),
#  ('pesos', 20971),
#  ('nacional', 20722),
#  ('días', 20528),
#  ('así', 20361),
#  ('van', 20198),
#  ('ser', 20058),
#  ('usted', 19578),
#  ('hacer', 19551),
#  ('gente', 19236),
#  ('ciento', 19213),
#  ('señor', 18702),
#  ('gracias', 17326),
#  ('bien', 16851),
#  ('tema', 16799),
#  ('tres', 16521),
#  ('años', 16429),
#  ('parte', 16354),
#  ('importante', 15963),
#  ('decir', 15865),
#  ('puede', 15561),
#  ('hoy', 15537),
#  ('poder', 15484),
#  ('todas', 15235),
#  ('día', 15177),
#  ('salud', 15110),
#  ('año', 15072),
#  ('seguridad', 15040),
#  ('hace', 14914),
#  ('manera', 14913),
#  ('tener', 14846),
#  ('mismo', 14814),
#  ('unidos', 14738),
#  ('personas', 14724),
#  ('tiempo', 14372),
#  ('general', 14199),
#  ('interlocutor', 13603),
#  ('buenos', 13582),
#  ('información', 13314),
#  ('interlocutora', 13036),
#  ('además', 12891),
#  ('luego', 12686),
#  ('secretaría', 12354),
#  ('voy', 12334),
#  ('muchas', 12008),
#  ('sólo', 11510),
#  ('ayer', 11409),
#  ('corrupción', 11225),
#  ('acuerdo', 11195),
#  ('haciendo', 11132),
#  ('trabajo', 10903),
#  ('ejemplo', 10346),
#  ('ustedes', 10290),
#  ('siempre', 10137),
#  ('ciudad', 10004),
#  ('pública', 9890),
#  ('federal', 9809),
#  ('toda', 9799),
#  ('creo', 9748),
#  ('mexicanos', 9372),
#  ('cada', 9254),
#  ('reforma', 9185),
#  ('empresas', 9013),
#  ('semana', 8999),
#  ('política', 8922),
#  ('haber', 8805),
#  ('dar', 8769),
#  ('mejor', 8734),
#  ('vez', 8705),
#  ('dinero', 8641),
#  ('menos', 8586),
#  ('trabajadores', 8560),
#  ('cuatro', 8549),
#  ('cosas', 8448),
#  ('hecho', 8347),
#  ('secretario', 8279),
#  ('proceso', 8264),
#  ('momento', 8154),
#  ('sino', 8134),
#  ('social', 8127),
#  ('apoyo', 8059),
#  ('centavos', 8048),
#  ('casos', 8011),
#  ('incluso', 8007),
#  ('bienestar', 7964),
#  ('todavía', 7945),
#  ('seguir', 7939),
#  ('programa', 7873),
#  ('cinco', 7758),
#  ('ir', 7747),
#  ('cabo', 7666),
#  ('prensa', 7600),
#  ('dice', 7600),
#  ('atención', 7582),
#  ('vida', 7513),
#  ('quién', 7453),
#  ('mundo', 7350),
#  ('asunto', 7280),
#  ('plan', 7276),
#  ('sido', 7269),
#  ('derecho', 7242),
#  ('medios', 7224),
#  ('pueden', 7217),
#  ('nuevo', 7023),
#  ('tren', 7015),
#  ('quiero', 7002),
#  ('mañana', 6989),
#  ('después', 6960),
#  ('problema', 6946),
#  ('intervención', 6927),
#  ('agua', 6876),
#  ('guardia', 6871),
#  ('gran', 6647),
#  ('podemos', 6604),
#  ('jóvenes', 6603),
#  ('recursos', 6567),
#  ('primera', 6554),
#  ('primero', 6534),
#  ('empresa', 6454),
#  ('público', 6430),
#  ('precio', 6424),
#  ('trabajando', 6417),
#  ('presupuesto', 6409),
#  ('pemex', 6400),
#  ('último', 6374),
#  ('situación', 6354),
#  ('hizo', 6343),
#  ('cuenta', 6332),
#  ('pasado', 6329),
#  ('ley', 6320),
#  ('conocer', 6312),
#  ('mayor', 6269),
#  ('presidenta', 6156),
#  ('fiscalía', 6144),
#  ('da', 6113),
#  ('justicia', 6111),
#  ('seis', 6059),
#  ('elementos', 6054),
#  ('baja', 6013),
#  ('países', 5992),
#  ('allá', 5988),
#  ('sistema', 5974),
#  ('hablando', 5952),
#  ('investigación', 5949),
#  ('transformación', 5869),
#  ('informar', 5828),
#  ('grupo', 5774),
#  ('sé', 5764),
#  ('construcción', 5760),
#  ('hacia', 5742),
#  ('preguntarle', 5736),
#  ('hicieron', 5726),
#  ('adelante', 5707),
#  ('veces', 5699),
#  ('queremos', 5698),
#  ('comisión', 5622),
#  ('favor', 5582),
#  ('mujeres', 5577),
#  ('primer', 5563),
#  ('violencia', 5556),
#  ('república', 5553),
#  ('desarrollo', 5470),
#  ('zona', 5459),
#  ('mucha', 5429),
#  ('sociales', 5425),
#  ('debe', 5423),
#  ('claro', 5404),
#  ('nivel', 5400),
#  ('lugar', 5396),
#  ('tipo', 5395),
#  ('respecto', 5343),
#  ('defensa', 5246),
#  ('video', 5214),
#  ('falta', 5213),
#  ('derechos', 5213),
#  ('decía', 5201),
#  ('nunca', 5199),
#  ('población', 5198),
#  ('gobernador', 5161),
#  ('jesús', 5150),
#  ('cuál', 5135),
#  ('informe', 5118),
#  ('veracruz', 5098),
#  ('conferencia', 5090),
#  ('comunicación', 5074),
#  ('maya', 5072),
#  ('mes', 5054),
#  ('través', 5008),
#  ('gas', 4960),
#  ('personal', 4951),
#  ('inversión', 4929),
#  ('aeropuerto', 4919),
#  ('servicio', 4914),
#  ('iba', 4878),
#  ('redes', 4868),
#  ('verdad', 4856),
#  ('periodo', 4825),
#  ('atender', 4786),
#  ('número', 4783),
#  ('dicho', 4770),
#  ('educación', 4769),
#  ('sonora', 4760),
#  ('médicos', 4754),
#  ('ramírez', 4728),
#  ('total', 4715),
#  ('buena', 4714),
#  ('vemos', 4703),
#  ('marina', 4701),
#  ('nadie', 4688),
#  ('siguiente', 4684),
#  ('forma', 4642),
#  ('segundo', 4613),
#  ('nueva', 4595),
#  ('judicial', 4572),
#  ('tan', 4525),
#  ('dónde', 4514),
#  ('protección', 4509),
#  ('municipios', 4488),
#  ('ningún', 4478),
#  ('respeto', 4465),
#  ('dólares', 4461),
#  ('llegar', 4456),
#  ('mayoría', 4454),
#  ('aunque', 4451),
#  ('proyecto', 4426),
#  ('meses', 4419),
#  ('medio', 4406),
#  ('seguro', 4404),
#  ('hospitales', 4383),
#  ('precisamente', 4380),
#  ('partir', 4365),
#  ('democracia', 4354),
#  ('cuanto', 4351),
#  ('dio', 4310),
#  ('economía', 4306),
#  ('dijo', 4304),
#  ('posible', 4269),
#  ('mexicano', 4268),
#  ('digo', 4249),
#  ('acciones', 4243),
#  ('cambio', 4243),
#  ('relación', 4242),
#  ('historia', 4223),
#  ('san', 4221),
#  ('centro', 4213),
#  ('ocho', 4212),
#  ('pueblos', 4200),
#  ('pueda', 4196),
#  ('secretaria', 4193),
#  ('solamente', 4180),
#  ('autoridades', 4169),
#  ('saber', 4154),
#  ('casi', 4154),
#  ('quieren', 4141),
#  ('administración', 4137),
#  ('sector', 4127),
#  ('viene', 4126),
#  ('ah', 4075),
#  ('sigue', 4070),
#  ('saben', 4069),
#  ('embargo', 4067),
#  ('dicen', 4037),
#  ('reunión', 4016),
#  ('instituto', 4015),
#  ('gobiernos', 4010),
#  ('puedo', 4008),
#  ('alguna', 4004),
#  ('independencia', 3999),
#  ('hacen', 3986),
#  ('director', 3986),
#  ('precios', 3978),
#  ('algún', 3953),
#  ('llevar', 3953),
#  ('imagínense', 3945),
#  ('podría', 3941),
#  ('pandemia', 3940)]
